# %% [markdown]
# # Auswertung PSCB1 Experiment Daten

# %%
# Read in data
import pandas as pd 
import scipy # For the entropy function
from scipy.stats import entropy
import statistics

df = pd.read_excel('/home/ansost/repos/CaSpaSyn/data/pscb1.xlsx') 
df.head()
# Out:
#    Lfd. Nr.   Code Researchers Language                 Date     Start
# 0         0  346IO   ABR/JS/AS        S  2023-05-15 00:00:00  12:17:00  \
# 1         1  346OL   ABR/JS/AS        S  2023-05-15 00:00:00  12:16:00
# 2         2  000NE   ABR/JS/AS        S  2023-05-15 00:00:00  12:55:00
# 3         3  UAI23   ABR/JS/AS        S  2023-05-15 00:00:00  12:55:00
# 4         4  RF107   ABR/JS/AS        S  2023-05-15 00:00:00  13:00:00
#
#         End   Check  4  7  ...  97  99 103  105  109  112  114  117  119
# 0  12:29:00  Niklas  6  6  ...   6   6   3    6    7    7    7    7    4  \
# 1  12:29:00  Niklas  7  6  ...   7   7   1    7    7    7    7    7    7
# 2  13:04:00  Niklas  7  4  ...   7   7   1    1    7    5    7    7    1
# 3  13:03:00  Niklas  7  7  ...   3   3   1    5    7    2    7    6    5
# 4  13:09:00  Niklas  7  7  ...   4   6   2    2    4    4    4    5    4
#
#                                             Comments
# 0                                                NaN
# 1                                                NaN
# 2  Muchas de estas oraciones son correctas gramat...
# 3  Hay que relacionar mejor las palabras para que...
# 4                                                NaN
#
# [5 rows x 49 columns]

# %% [markdown]
# ### Item analysis
# To examine the variability of the phenomenon, Shannon entropy (base 2) was used to quantify how variable are the items in the experimental data and how variable are the participants.
# Additionally, the mean rating and te standard deviation is given.
#
#
# **by items:**
# - entropy of each experimental item (non-filler) over all participants
# - Column vector of answers for the given item, turned into a probabiliy distribution and thrown into the entropy function by scipy

# %%
subset = df.iloc[:, 8:48]

for item in subset.columns:
    # Get the current column from the dataframe 
    col = subset[item].tolist()
    
    # Check if there are any NA values and if yes replace them with 0     
    if 'X' in col or 'NA' in col:
        col = subset[item].replace('X', 0)
    
    # Turn into proportions
    proportions = [n / sum(col) for n in col]
    
    # Compute entropy
    entropy_ = scipy.stats.entropy(proportions) 
    stdev = statistics.stdev(col)
    mean = statistics.mean(col)
    median = statistics.median(col)
    print(entropy_, stdev, round(mean, 0), median)
# Out:
# 2.6367422535961182 0.4688072309384954 7.0 7.0
# 2.6186818678278545 1.2066664642907567 6.0 6.0
# 2.5483146503584773 0.9168747682531899 2.0 2.0
# 2.594098889111395 1.6052797503622467 6.0 6.0
# 2.4383299114211106 1.42389343964797 2.0 2.0
# 2.63770687739093 0.36313651960128146 7.0 7.0
# 2.609996298316065 1.4064216928154862 6.0 6.5
# 2.5112034600567728 1.8985245861972935 4.0 4.0
# 2.617291308073473 1.2838814775327387 6.0 7.0
# 2.4303981068673313 1.8883680959850138 3.0 2.0
# 2.6043875470831646 1.489892687336984 6.0 6.0
# 2.48141524004558 1.5898026693500447 3.0 2.5
# 2.6239667382928373 1.0818177620697815 7.0 7.0
# 2.5597631495067503 2.023216892329291 5.0 6.5
# 2.5917755659126893 1.7743595036946849 6.0 7.0
# 2.4364735122658456 2.31098665955893 4.0 3.0
# 2.6062458865095026 1.3827826698682306 5.0 6.0
# 2.53406744744208 2.1277858274442303 5.0 4.5
# 2.6346148647430687 0.6333236937766509 7.0 7.0
# 2.4273686832407626 1.5776599725577718 2.0 1.5
# 2.6009780437383325 1.549547966698321 6.0 6.0
# 2.5575987172138213 2.064881658530644 6.0 6.5
# 2.4302752912127192 2.4371213428059835 4.0 3.0
# 2.581238164957219 1.8292495308606331 6.0 6.5
# 2.625022621352435 1.027105182026191 6.0 6.0
# 2.6325581076039364 0.7559289460184545 7.0 7.0
# 2.621128505658922 1.167320591199077 6.0 7.0
# 2.619528587356883 1.2224996910042532 6.0 7.0
# 2.5500451531745605 2.05554730553075 5.0 5.5
# 2.630202977984569 0.8548504142651103 6.0 7.0
# 2.5433372996988552 2.14322341192107 5.0 6.0
# 2.545203776295049 2.0326997151247235 5.0 5.5
# 2.5832143202089184 1.7478401113789142 6.0 6.0
# 2.424200118538212 1.6723346844167577 2.0 2.0
# 2.350823447045187 2.584824690635456 3.0 2.0
# 2.582029519502334 1.8999710813299528 6.0 7.0
# 2.6034604547031392 1.5191090506254998 6 7.0
# 2.631529512563561 0.8017837257372732 7.0 7.0
# 2.596568411058051 1.6391501416322993 6.0 7.0
# 2.5591190790282354 2.0164161440372537 5.0 6.0

# %% [markdown]
# ### Participant analysis
# To examine the variability of the phenomenon, Shannon entropy (base 2) was used to quantify how variable are the items in the experimental data and how variable are the participants.
# Additionally, mean rating and its standard deviation are given.
#
#
# **by participants:**
#  - entropy of answers by the participants over all items
#  - Row vector of answers of the given participant, turned into a probability distribution and thrown into the entropy function by scipy
